# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd

iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
np.random.seed(0)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.drop(["Species"], axis=1), iris["Species"], test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

print("Genauigkeit der Testdaten: {:.4f}".format(knn.score(X_test, y_test)))
# Out:
# Genauigkeit der Testdaten: 0.9778

# %% [markdown]
# ## Auswerten der Ergebnisse

# %%
# %run confusion_matrix_style.py

y_pred = knn.predict(X_test)
cnf_matrix = confusion_matrix(y_test, y_pred, labels=y_test.unique())
plot_confusion_matrix(cnf_matrix, classes=y_test.unique(), normalize=True, title='Normalisierte Konfusionsmatrix des k-Nearest-Neighbor')

plt.show()
# Out:
# Normalized confusion matrix
